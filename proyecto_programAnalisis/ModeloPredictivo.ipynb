# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
csv ='/Users/LICITACIONES/Documents/Proyectos PY/proyecto_programAnalisis/Spotify_Youtube.csv'
df=pd.read_csv(csv)
df
# Out:
#        Unnamed: 0       Artist
# 0               0     Gorillaz  \
# 1               1     Gorillaz
# 2               2     Gorillaz
# 3               3     Gorillaz
# 4               4     Gorillaz
# ...           ...          ...
# 20713       20713  SICK LEGEND
# 20714       20714  SICK LEGEND
# 20715       20715  SICK LEGEND
# 20716       20716  SICK LEGEND
# 20717       20717  SICK LEGEND
#
#                                              Url_spotify
# 0      https://open.spotify.com/artist/3AA28KZvwAUcZu...  \
# 1      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...                                                  ...
# 20713  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20718 non-null  int64
#  1   Artist            20718 non-null  object
#  2   Url_spotify       20718 non-null  object
#  3   Track             20718 non-null  object
#  4   Album             20718 non-null  object
#  5   Album_type        20718 non-null  object
#  6   Uri               20718 non-null  object
#  7   Danceability      20716 non-null  float64
#  8   Energy            20716 non-null  float64
#  9   Key               20716 non-null  float64
#  10  Loudness          20716 non-null  float64
#  11  Speechiness       20716 non-null  float64
#  12  Acousticness      20716 non-null  float64
#  13  Instrumentalness  20716 non-null  float64
#  14  Liveness          20716 non-null  float64
#  15  Valence           20716 non-null  float64
# ...

# %%
total_null = df.isnull().sum().sort_values(ascending = False)
porcentaje = ((df.isnull().sum()/df.isnull().count())*100).sort_values(ascending = False)
print("Total records = ", df.shape[0])

missing_data = pd.concat([total_null,porcentaje.round(2)],axis=1,keys=['Total nulls','porcentaje'])
missing_data
# Out:
# Total records =  20718
#                   Total nulls  porcentaje
# Description               876        4.23
# Stream                    576        2.78
# Comments                  569        2.75
# Likes                     541        2.61
# official_video            470        2.27
# Licensed                  470        2.27
# Views                     470        2.27
# Channel                   470        2.27
# Title                     470        2.27
# Url_youtube               470        2.27
# Valence                     2        0.01
# Duration_ms                 2        0.01
# Tempo                       2        0.01
# Liveness                    2        0.01
# Instrumentalness            2        0.01
# Acousticness                2        0.01
# Speechiness                 2        0.01
# Loudness                    2        0.01
# Key                         2        0.01
# Energy                      2        0.01
# Danceability                2        0.01
# ...

# %%
df.dropna(axis=0,inplace=True)

# %%
df.nunique()
# Out:
# Unnamed: 0          19170
# Artist               2040
# Url_spotify          2040
# Track               16547
# Album               11224
# Album_type              3
# Uri                 17479
# Danceability          893
# Energy               1248
# Key                    12
# Loudness             8978
# Speechiness          1259
# Acousticness         3087
# Instrumentalness     3883
# Liveness             1512
# Valence              1280
# Tempo               14047
# Duration_ms         13792
# Url_youtube         17179
# Title               17173
# Channel              6200
# Views               18250
# Likes               17219
# Comments            10280
# Description         16820
# Licensed                2
# official_video          2
# Stream              17609
# dtype: int64

# %%
#Lista de Temas/Columnas a relacionar
features = """Danceability
Energy
Key
Loudness
Speechiness
Acousticness
Instrumentalness
Liveness
Valence
Tempo
Duration_ms
Stream
Views
Likes"""
features = features.split('\n')
df_feat = df[features]
corr_df = df_feat.corr()
abs(corr_df['Likes']).sort_values(ascending=False)[0:]
# Out:
# Likes               1.000000
# Views               0.891852
# Stream              0.656785
# Loudness            0.123731
# Danceability        0.099296
# Instrumentalness    0.081171
# Acousticness        0.078123
# Energy              0.061980
# Liveness            0.023562
# Speechiness         0.014429
# Valence             0.013986
# Key                 0.007948
# Duration_ms         0.005841
# Tempo               0.002287
# Name: Likes, dtype: float64

# %%
df_feat.corr()
# Out:
#                   Danceability    Energy       Key  Loudness  Speechiness
# Danceability          1.000000  0.237308  0.040010  0.358489     0.227250  \
# Energy                0.237308  1.000000  0.032441  0.745109     0.091493
# Key                   0.040010  0.032441  1.000000  0.028907     0.022568
# Loudness              0.358489  0.745109  0.028907  1.000000     0.070431
# Speechiness           0.227250  0.091493  0.022568  0.070431     1.000000
# Acousticness         -0.280314 -0.661459 -0.031197 -0.552748    -0.099049
# Instrumentalness     -0.322392 -0.316586 -0.000131 -0.557273    -0.112720
# Liveness             -0.081334  0.174765 -0.007418  0.086952     0.065696
# Valence               0.464737  0.391466  0.044923  0.316783     0.061185
# Tempo                -0.063116  0.156221  0.000744  0.143877     0.051544
# Duration_ms          -0.090393  0.022895  0.003057  0.010756    -0.049266
# Stream                0.072299  0.044376 -0.006250  0.118746    -0.015688
# ...

# %% [markdown]
# Loudness            0.118406
# Stream              0.604195
# Likes               0.891852

# %%
sns.regplot(x='Views', y='Likes', data=df,scatter_kws={"color": "red"}, line_kws={"color": "blue"}).set(title="Relacion entre Likes y Vistas")
plt.ylim(0,)
# Out:
# (0.0, 53328084.6)

# %%
# fig = sns.scatterplot(df,x='Stream',y='Views')
# fig.set_title("Relacion entre Stream y Views",fontsize=15)
sns.regplot(x='Stream', y='Likes', data=df,scatter_kws={"color": "red"}, line_kws={"color": "blue"}).set(title="Relacion entre Stream y Likes")
plt.ylim(0,)
# Out:
# (0.0, 53329034.70252957)

# %%
# fig = sns.scatterplot(df,x='Loudness',y='Views')
# fig.set_title("Relacion entre Volumen y Likes",fontsize=15)
sns.regplot(x='Loudness', y='Likes', data=df,scatter_kws={"color": "red"}, line_kws={"color": "blue"}).set(title="Relacion entre Volumen y Likes")
plt.ylim(0,)
# Out:
# (0.0, 53394757.823935166)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))

    ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    ax2 = sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)

    plt.title(Title)
    plt.xlabel('Views')
    plt.ylabel('Proporcion de Canciones')

    plt.show()
    plt.close()

def PollyPlot(xtrain, xtest, y_train, y_test, lr,poly_transform):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    
    
    #training data 
    #testing data 
    # lr:  linear regression object 
    #poly_transform:  polynomial transformation object 
 
    xmax=max([xtrain.values.max(), xtest.values.max()])

    xmin=min([xtrain.values.min(), xtest.values.min()])

    x=np.arange(xmin, xmax, 0.1)


    plt.plot(xtrain, y_train, 'ro', label='Training Data')
    plt.plot(xtest, y_test, 'go', label='Test Data')
    plt.plot(x, lr.predict(poly_transform.fit_transform(x.reshape(-1, 1))), label='Predicted Function')
    plt.ylim([-10000, 60000])
    plt.ylabel('Views')
    plt.legend()

# %% [markdown]
# DIVISION DE BASES DE DATOS, PARA ENTRENAMIENTO Y TESTEO

# %%
y_data = df['Likes']
x_data=df.drop('Likes',axis=1)
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.30, random_state=1)
print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 5751
# number of training samples: 13419

# %% [markdown]
# Linear Regression

# %%
lr = LinearRegression()
lr.fit(x_train[['Stream']], y_train)
lr.score(x_test[['Stream']], y_test)
# Out:
# 0.41896027443248574

# %%
Yhat=lr.predict(x_test[['Stream']])
print('The mean square error is: ', \
      mean_squared_error(y_test, Yhat))
# Out:
# The mean square error is:  1734360704908.7966

# %% [markdown]
# Linear Regression
# R2 = 0.41896027443248574
# MSE = 1734360704908.7966

# %%
Title= 'Distribucion'
DistributionPlot(y_test,Yhat,"Actual Values (Test)","Predicted Values (Test)",Title)
# Out:
# C:\Users\LICITACIONES\AppData\Local\Temp\ipykernel_8032\1546876814.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
# C:\Users\LICITACIONES\AppData\Local\Temp\ipykernel_8032\1546876814.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# Multiple Linear Regression

# %%
lr.fit(x_train[['Stream','Loudness','Views'
]],y_train)
Yhat_test2 = lr.predict(x_test[['Stream','Loudness','Views'
]]) 
lr.score(x_test[['Stream','Loudness','Views'
]], y_test)
# Out:
# 0.8162641101972095

# %%
print('The mean square error of price and predicted value using multifit is: ', \
      mean_squared_error(y_test, Yhat_test2))
# Out:
# The mean square error of price and predicted value using multifit is:  548438072877.31714

# %% [markdown]
# Multiple Linear Regression
# R2 = 0.8162641101972095
# MSE = 548438072877.31714

# %%
pr = PolynomialFeatures(degree=3)
x_train_pr = pr.fit_transform(x_train[['Stream','Loudness','Views'
]])
x_test_pr = pr.fit_transform(x_test[['Stream','Loudness','Views'
]])

# %%
poly=lr.fit(x_train_pr,y_train)
yhat_test1=poly.predict(x_test_pr)
lr.score(x_test_pr, y_test)
# Out:
# 0.7259215824062838

# %%
print('The mean square error is: ', \
      mean_squared_error(y_test, yhat_test1))
# Out:
# The mean square error is:  818103851804.3488

# %% [markdown]
# Polynomial
# R2 = 0.7259215824062838
# MSE = 818103851804.3488

# %%
Title='Distribution  Plot '

DistributionPlot(y_test, yhat_test1, "Actual Values (Test)", "Predicted Values (Test)", Title)
# Out:
# C:\Users\Cifu\AppData\Local\Temp\ipykernel_7232\1546876814.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
# C:\Users\Cifu\AppData\Local\Temp\ipykernel_7232\1546876814.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# MODELO SELECCIONADO: MLR

# %%
lr.fit(x_train[['Stream','Loudness','Views'
]],y_train)
Yhat_test2 = lr.predict(x_test[['Stream','Loudness','Views'
]]) 
lr.score(x_test[['Stream','Loudness','Views'
]], y_test)
# Out:
# 0.8162641101972095

# %%
Title= 'Prueba Grafica del Funcionamiento del Modelo'
DistributionPlot(y_test,Yhat_test2,"Actual Values (Test)","Predicted Values (Test)",Title)
# Out:
# C:\Users\LICITACIONES\AppData\Local\Temp\ipykernel_5592\1546876814.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
# C:\Users\LICITACIONES\AppData\Local\Temp\ipykernel_5592\1546876814.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...
